# %%
import pandas as pd

# %%
df = pd.read_csv('54fba223-5ddc-4139-9503-43cf7c5f8eea_Data.csv')

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name      Series Code  \
# 0                 Agricultural land (% of land area)   AG.LND.AGRI.ZS
# 1  Annual CO2 combustion emissions at operating c...  CC.COAL.EMIS.CO
# 2  Annual CO2 combustion emissions at proposed co...  CC.COAL.EMPR.CO
# 3   Annual coal production (Mt per year) - Operating  CC.COAL.PROD.OP
# 4  Annual coal production (Mt per year) - Propose...  CC.COAL.PROD.PR
#
#   1990 [YR1990] 1991 [YR1991] 1992 [YR1992] 1993 [YR1993] 1994 [YR1994]  \
# 0   58.32298422   58.30765221   58.30765221   58.16046487   57.97494749
# 1            ..            ..            ..            ..            ..
# 2            ..            ..            ..            ..            ..
# 3            ..            ..            ..            ..            ..
# ...

# %%
df['Series Code'].unique()
# Out:
# array(['AG.LND.AGRI.ZS', 'CC.COAL.EMIS.CO', 'CC.COAL.EMPR.CO',
#        'CC.COAL.PROD.OP', 'CC.COAL.PROD.PR', 'CC.COAL.EMIS.CH',
#        'CC.COAL.EMPR.CH', 'AG.LND.ARBL.ZS', 'CC.PRO.ANI',
#        'CC.CO2.EMSE.BL', 'CC.CO2.EMSE.BF', 'CC.CO2.EMSE.EH',
#        'CC.CO2.EMSE.EN', 'CC.CO2.EMSE.FE', 'CC.CO2.EMSE.IP',
#        'CC.CO2.EMSE.LU', 'CC.CO2.EMSE.MC', 'CC.CO2.EMSE.OF',
#        'CC.CO2.EMSE.EL', 'CC.CO2.EMSE.IL', 'CC.CO2.EMSE.TR',
#        'CC.ELEC.CON', 'CC.ELEC.GEN', 'CC.ECH.AFO', 'CC.ECH.BCR',
#        'CC.ECH.EAL', 'CC.ECH.EFE', 'CC.ECH.FGE', 'CC.ECH.FTR',
#        'CC.ECH.FOS', 'CC.ECH.FFR', 'CC.ECH.IPA', 'CC.ECH.LUC',
#        'CC.ECH.LUL', 'CC.ECH.MMA', 'CC.ECH.OEU', 'CC.ECH.RCA',
#        'CC.ECH.SVF', 'CC.ECO.AFO', 'CC.ECO.DOC', 'CC.ECO.EAL',
#        'CC.ECO.FGE', 'CC.ECO.FOS', 'CC.ECO.FOR', 'CC.ECO.LUC',
#        'CC.ECO.LUL', 'CC.ECO.NFC', 'CC.ECO.OEU', 'CC.EAR.AFO',
#        'CC.EAR.AGS', 'CC.EAR.BCR', 'CC.EAR.DOS', 'CC.EAR.CRE',
# ...

# %%
df_filtered = df.loc[df['Series Code'].isin(['AG.LND.AGRI.ZS','AG.LND.ARBL.ZS','CC.CO2.EMSE.BL','CC.CO2.EMSE.BF','CC.CO2.EMSE.EH','CC.CO2.EMSE.EN','CC.CO2.EMSE.FE','CC.CO2.EMSE.IP','CC.CO2.EMSE.LU','CC.CO2.EMSE.MC','CC.CO2.EMSE.OF','CC.CO2.EMSE.EL','CC.CO2.EMSE.IL','CC.CO2.EMSE.TR','CC.ELEC.CON','NY.GDP.MKTP.CD','NY.GDP.MKTP.KD.ZG','NY.GDP.PCAP.CD','CC.GHG.GRPE','CC.EG.CONS.COAL.PC','CC.EG.CONS.GAS.PC','CC.EG.CONS.OIL.PC','CC.GHG.PECA','SP.POP.TOTL','AG.LND.FRST.ZS','SP.URB.TOTL.IN.ZS'])]

# %%
df_filtered['Series Code'].unique()
# Out:
# array(['AG.LND.AGRI.ZS', 'AG.LND.ARBL.ZS', 'CC.CO2.EMSE.BL',
#        'CC.CO2.EMSE.BF', 'CC.CO2.EMSE.EH', 'CC.CO2.EMSE.EN',
#        'CC.CO2.EMSE.FE', 'CC.CO2.EMSE.IP', 'CC.CO2.EMSE.LU',
#        'CC.CO2.EMSE.MC', 'CC.CO2.EMSE.OF', 'CC.CO2.EMSE.EL',
#        'CC.CO2.EMSE.IL', 'CC.CO2.EMSE.TR', 'CC.ELEC.CON',
#        'NY.GDP.MKTP.CD', 'NY.GDP.MKTP.KD.ZG', 'NY.GDP.PCAP.CD',
#        'CC.GHG.GRPE', 'CC.EG.CONS.COAL.PC', 'CC.EG.CONS.GAS.PC',
#        'CC.EG.CONS.OIL.PC', 'CC.GHG.PECA', 'SP.POP.TOTL',
#        'AG.LND.FRST.ZS', 'SP.URB.TOTL.IN.ZS'], dtype=object)

# %%
from pathlib import Path  
filepath = Path('filtered_data.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_filtered.to_csv(filepath)

# %%
# Renaming the year columns.

df_filtered = df_filtered.rename(columns={'1990 [YR1990]':'1990','1991 [YR1991]':'1991','1992 [YR1992]':'1992','1993 [YR1993]':'1993','1994 [YR1994]':'1994','1995 [YR1995]':'1995','1996 [YR1996]':'1996','1997 [YR1997]':'1997','1998 [YR1998]':'1998','1999 [YR1999]':'1999','2000 [YR2000]':'2000','2001 [YR2001]':'2001','2002 [YR2002]':'2002','2003 [YR2003]':'2003','2004 [YR2004]':'2004','2005 [YR2005]':'2005','2006 [YR2006]':'2006','2007 [YR2007]':'2007','2008 [YR2008]':'2008','2009 [YR2009]':'2009','2010 [YR2010]':'2010','2011 [YR2011]':'2011','2012 [YR2012]':'2012','2013 [YR2013]':'2013','2014 [YR2014]':'2014','2015 [YR2015]':'2015','2016 [YR2016]':'2016','2017 [YR2017]':'2017','2018 [YR2018]':'2018','2019 [YR2019]':'2019','2020 [YR2020]':'2020','2021 [YR2021]':'2021','2022 [YR2022]':'2022','2023 [YR2023]':'2023','2024 [YR2024]':'2024','2025 [YR2025]':'2025','2026 [YR2026]':'2026'})

# %%
# Getting the year columns as an array so I can easily copy and paste it.

Year_column_list = df_filtered.columns.values
Year_column_list[4:]
# Out:
# array(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '2023', '2024', '2025', '2026'], dtype=object)

# %%
# Using pd.melt() to flatten the table. id_vars is the list of columns not to transpose. value_vars is the list of columsn that will be transpose. 

df_melt = pd.melt(df_filtered, id_vars=['Country Name','Country Code','Series Name','Series Code'], value_vars=['1990','1991','1992','1993','1994','1995','1996','1997','1998','1999','2000', '2001','2002','2003','2004','2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
       '2022', '2023', '2024', '2025', '2026'], var_name='Year', value_name='Value')
df_melt
# Out:
#        Country Name Country Code  \
# 0       Afghanistan          AFG
# 1       Afghanistan          AFG
# 2       Afghanistan          AFG
# 3       Afghanistan          AFG
# 4       Afghanistan          AFG
# ...             ...          ...
# 211635     Zimbabwe          ZWE
# 211636     Zimbabwe          ZWE
# 211637     Zimbabwe          ZWE
# 211638     Zimbabwe          ZWE
# 211639     Zimbabwe          ZWE
#
#                                               Series Name        Series Code  \
# 0                      Agricultural land (% of land area)     AG.LND.AGRI.ZS
# 1                            Arable land (% of land area)     AG.LND.ARBL.ZS
# 2          CO2 emissions by sector (Mt CO2 eq) - Building     CC.CO2.EMSE.BL
# 3       CO2 emissions by sector (Mt CO2 eq) - Bunker F...     CC.CO2.EMSE.BF
# 4       CO2 emissions by sector (Mt CO2 eq) - Electric...     CC.CO2.EMSE.EH
# ...                                                   ...                ...
# ...

# %%
from pathlib import Path
filepath_melt = Path('melted_data.csv')  
filepath_melt.parent.mkdir(parents=True, exist_ok=True)  
df_melt.to_csv(filepath_melt)
