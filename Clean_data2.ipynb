# %%
import pandas as pd
import numpy as py

# %%
df=pd.read_csv("C:/Users/Jorge/Downloads/filtered_data.csv")

# %%
df.head()
# Out:
#   country_name country_code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series_name     Series_code  \
# 0                 Agricultural land (% of land area)  AG.LND.AGRI.ZS
# 1                       Arable land (% of land area)  AG.LND.ARBL.ZS
# 2     CO2 emissions by sector (Mt CO2 eq) - Building  CC.CO2.EMSE.BL
# 3  CO2 emissions by sector (Mt CO2 eq) - Bunker F...  CC.CO2.EMSE.BF
# 4  CO2 emissions by sector (Mt CO2 eq) - Electric...  CC.CO2.EMSE.EH
#
#   1990 [YR1990] 1991 [YR1991] 1992 [YR1992] 1993 [YR1993] 1994 [YR1994]  \
# 0   58.32298422   58.30765221   58.30765221   58.16046487   57.97494749
# 1   12.12762369   12.12762369   12.12762369   11.99576836   11.81025099
# 2          0.08          0.07          0.03          0.03          0.02
# 3          0.02          0.02          0.02          0.02          0.02
# ...

# %%
#Rename year columns 
df1=df.rename(columns={'1990 [YR1990]':'YR1990','1991 [YR1991]':'YR1991', '1992 [YR1992]':'YR1992', '1993 [YR1993]':'YR1993', '1994 [YR1994]':'YR1994',
       '1995 [YR1995]':'YR1995', '1996 [YR1996]':'YR1996', '1997 [YR1997]':'YR1997', '1998 [YR1998]': 'YR1998',
       '1999 [YR1999]':'YR1999', '2000 [YR2000]':'YR2000', '2001 [YR2001]':'YR2001', '2002 [YR2002]':'YR2002',
       '2003 [YR2003]':'YR2003', '2004 [YR2004]':'YR2004', '2005 [YR2005]':'YR2005', '2006 [YR2006]':'YR2006',
       '2007 [YR2007]':'YR2007', '2008 [YR2008]':'YR2008', '2009 [YR2009]':'YR2009', '2010 [YR2010]':'YR2010',
       '2011 [YR2011]':'YR2011', '2012 [YR2012]':'YR2012', '2013 [YR2013]':'YR2013', '2014 [YR2014]':'YR2014',
       '2015 [YR2015]':'YR2015', '2016 [YR2016]':'YR2016', '2017 [YR2017]':'YR2017', '2018 [YR2018]':'YR2018',
       '2019 [YR2019]':'YR2019', '2020 [YR2020]':'YR2020', '2021 [YR2021]':'YR2021', '2022 [YR2022]':'YR2022',
       '2023 [YR2023]':'YR2023', '2024 [YR2024]':'YR2024', '2025 [YR2025]':'YR2025', '2026 [YR2026]':'YR2026'})
df1.columns
# Out:
# Index(['country_name', 'country_code', 'Series_name', 'Series_code', 'YR1990',
#        'YR1991', 'YR1992', 'YR1993', 'YR1994', 'YR1995', 'YR1996', 'YR1997',
#        'YR1998', 'YR1999', 'YR2000', 'YR2001', 'YR2002', 'YR2003', 'YR2004',
#        'YR2005', 'YR2006', 'YR2007', 'YR2008', 'YR2009', 'YR2010', 'YR2011',
#        'YR2012', 'YR2013', 'YR2014', 'YR2015', 'YR2016', 'YR2017', 'YR2018',
#        'YR2019', 'YR2020', 'YR2021', 'YR2022', 'YR2023', 'YR2024', 'YR2025',
#        'YR2026'],
#       dtype='object')

# %%
df1.head()
# Out:
#   country_name country_code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series_name     Series_code  \
# 0                 Agricultural land (% of land area)  AG.LND.AGRI.ZS
# 1                       Arable land (% of land area)  AG.LND.ARBL.ZS
# 2     CO2 emissions by sector (Mt CO2 eq) - Building  CC.CO2.EMSE.BL
# 3  CO2 emissions by sector (Mt CO2 eq) - Bunker F...  CC.CO2.EMSE.BF
# 4  CO2 emissions by sector (Mt CO2 eq) - Electric...  CC.CO2.EMSE.EH
#
#         YR1990       YR1991       YR1992       YR1993       YR1994  \
# 0  58.32298422  58.30765221  58.30765221  58.16046487  57.97494749
# 1  12.12762369  12.12762369  12.12762369  11.99576836  11.81025099
# 2         0.08         0.07         0.03         0.03         0.02
# 3         0.02         0.02         0.02         0.02         0.02
# ...

# %%
# Eliminate ..
df2=df1.replace('..','')

# %%
#Check in CSV
df2.to_csv('filtered_data2.csv', index=False)
